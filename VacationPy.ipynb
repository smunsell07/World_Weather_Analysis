# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests

#Import the API key.
from config import g_key

# %%
# Store the saved CSV into a DataFrame.
city_data_df=pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID             City Country                 Date      Lat       Lng  \
# 0        0       Nagornskiy      RU  2022-04-06 20:29:04  58.7731   57.5451
# 1        1  Yangi Marg`ilon      UZ  2022-04-06 20:29:04  40.4272   71.7189
# 2        2        Kysyl-Syr      RU  2022-04-06 20:29:05  63.8986  122.7617
# 3        3           Nsanje      MW  2022-04-06 20:29:05 -16.9200   35.2620
# 4        4       Novoagansk      RU  2022-04-06 20:29:06  61.9449   76.6625
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     31.78        94         100        9.19
# 1     63.32        48          26        4.61
# 2    -16.78       100         100        1.72
# 3     75.13        97         100        2.28
# 4     22.78        94         100       17.07

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
#max_temp=city_data_df["Max Temp"]

#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
#temps=[]
#for temp in max_temp:
#    temps.append(max(temp,0))

# %%
# Heatmap of temperature
# Get the latitude and longitude
locations=city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp=city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], 
                                 dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations=city_data_df[["Lat", "Lng"]]
humidity=city_data_df["Humidity"]
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer=gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations=city_data_df[["Lat", "Lng"]]
clouds=city_data_df["Cloudiness"]
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer=gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations=city_data_df[["Lat", "Lng"]]
wind=city_data_df["Wind Speed"]
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer=gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp=float(input("What is the minimum temperature you would like for your trip?"))
max_temp=float(input("What is the maximum temperature you would like for your trip?"))
# Out:
# What is the minimum temperature you would like for your trip?75
# What is the maximum temperature you would like for your trip?90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df=city_data_df.loc[(city_data_df["Max Temp"]<=max_temp) & \
                                     (city_data_df["Max Temp"]>=min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID           City Country                 Date      Lat       Lng  \
# 3         3         Nsanje      MW  2022-04-06 20:29:05 -16.9200   35.2620
# 9         9          Kapaa      US  2022-04-06 20:29:08  22.0752 -159.3190
# 15       15   Puerto Ayora      EC  2022-04-06 20:29:10  -0.7393  -90.3518
# 18       18           Tual      ID  2022-04-06 20:29:11  -5.6667  132.7500
# 19       19  Mar del Plata      AR  2022-04-06 20:27:41 -38.0023  -57.5575
# 28       28       Vallenar      CL  2022-04-06 20:29:14 -28.5708  -70.7581
# 29       29       Benguela      AO  2022-04-06 20:29:15 -12.5763   13.4055
# 34       34        Rikitea      PF  2022-04-06 20:24:29 -23.1203 -134.9692
# 35       35        Palauig      PH  2022-04-06 20:29:17  15.4350  119.9045
# 43       43    Grand Gaube      MU  2022-04-06 20:29:20 -20.0064   57.6608
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 3      75.13        97         100        2.28
# 9      78.78        73           0       17.27
# 15     85.96        80          63        9.19
# 18     82.27        75         100        5.66
# 19     80.62        39           0       16.11
# 28     88.02        10           0       10.20
# 29     75.83        86          41        3.65
# 34     78.53        73          63       14.12
# 35     79.16        78          96        2.44
# 43     79.20        86          60       16.28

# %%
preferred_cities_df.count()
# Out:
# City_ID       195
# City          195
# Country       195
# Date          195
# Lat           195
# Lng           195
# Max Temp      195
# Humidity      195
# Cloudiness    195
# Wind Speed    195
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names, city, country, max temp, and coordinates.
hotel_df=preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"]=""
hotel_df.head(10)
# Out:
#              City Country  Max Temp      Lat       Lng Hotel Name
# 3          Nsanje      MW     75.13 -16.9200   35.2620
# 9           Kapaa      US     78.78  22.0752 -159.3190
# 15   Puerto Ayora      EC     85.96  -0.7393  -90.3518
# 18           Tual      ID     82.27  -5.6667  132.7500
# 19  Mar del Plata      AR     80.62 -38.0023  -57.5575
# 28       Vallenar      CL     88.02 -28.5708  -70.7581
# 29       Benguela      AO     75.83 -12.5763   13.4055
# 34        Rikitea      PF     78.53 -23.1203 -134.9692
# 35        Palauig      PH     79.16  15.4350  119.9045
# 43    Grand Gaube      MU     79.20 -20.0064   57.6608

# %%
# Set parameters to search for a hotel.
params={
    "radius":5000,
    "type":"lodging",
    "key": g_key, 
    "location":""}

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()

# %%
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEAYO7jkwhBmfsaFaRr1no-yo7x6WKk_mKXo92wmBCA4oVYWgIVwWxMrv-b8Cfpd1mrh7shXji6VNdM3aNA-TRnsnrJSkQdUGaJp6sYTN5FwUd3cN9HualC6mr4QDglN4kU42q0EoDT9S4S9d4zkUPtkFLX84XXQdTWj8Mg5To8zRTRV2_wwuDpVLztN2jPNw7WnEVDbgfBjiQetgVc9kdCLU004fw51U7pNRUoGyv7xbvzLTrQw3aIH540eiP1L4sjWZQP7VJGCmCs2sygYgSJ1uVFkg-X0O-m3seGowIx-zcGCVRLNlN9UigAR_SnhtPHqRPR3fBVHoq42ePvp5AYsZWnIg0YsUurgUvJjunhyom86b0bhySb13O1cP-cG2OhtC8yuHm5u8cwmcnfnMdjE6Uksidwkowr0Ea4RBY9-rjZrjQZW1n3F',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.9613817, 'lng': -40.31222019999999},
#     'viewport': {'northeast': {'lat': -5.960069569708497,
#       'lng': -40.31068876970849},
#      'southwest': {'lat': -5.962767530291502, 'lng': -40.31338673029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Chácara Paraíso',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117028347333383155525">Everto Oliveira</a>'],
#      'photo_reference': 'Aap_uECXURhvaCpATQw9stMoVlAYMWvk1DJdvpK0jOsR__73F6o480QF4rGvOB3boBpvM2gtDkKirqGbXKkNh9R1kfGlSsCyrAkaAAiDS739dB4IWrk5oRVuQ_9m4hX9SIlgGoUGLOucjsfOa1SQjEYhQLiaVTFPS4t06dOr9QC3oeDHmdcc',
#      'width': 1920}],
#    'place_id': 'ChIJx4RNZPAhmAcRBcLmrx_YIrs',
#    'reference': 'ChIJx4RNZPAhmAcRBcLmrx_YIrs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '2MQQ+C4, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.9825518, 'lng': -40.29650640000001},
#     'viewport': {'northeast': {'lat': -5.981212069708499,
#       'lng': -40.2950858197085},
#      'southwest': {'lat': -5.983910030291503, 'lng': -40.2977837802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Love Star Motel',
#    'photos': [{'height': 774,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102296819575431218053">Ivaneide Silva sim</a>'],
#      'photo_reference': 'Aap_uEDc3d5bDRd2OZ46sWq_9CXcF6UF4cP8RBJoj6GC5TVQAyxtO8xCiMtmBWw7E9-MQxpTqyPwr3iqt5m6KBbBswFqMaGAvaZe2V_hHkRIpeXbXFRhSGXIYo9dHNkl6tkfFczEh7CMHk3Xcuwp24iPMB05z4W73qNF65ptTdMns9bhFzHo',
#      'width': 1032}],
#    'place_id': 'ChIJy36Tg5wfmAcRU-wxXy1ZGmo',
#    'plus_code': {'compound_code': '2P83+X9 José Alexandrino Nogueira, Tauá - CE, Brazil',
#     'global_code': '686X2P83+X9'},
#    'rating': 4,
#    'reference': 'ChIJy36Tg5wfmAcRU-wxXy1ZGmo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 84,
#    'vicinity': 'Avenida Chermont Alves de Oliveira, S/N - José Alexandrino Nogueira, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.9872378, 'lng': -40.29316840000001},
#     'viewport': {'northeast': {'lat': -5.985874369708498,
#       'lng': -40.29187201970851},
#      'southwest': {'lat': -5.988572330291503, 'lng': -40.29456998029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Aldeota City',
#    'photos': [{'height': 2560,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110884667853548399274">Gildo alves venasio Francisco</a>'],
#      'photo_reference': 'Aap_uEBscWdshkzka6u67z3MQ9EjcG9GhINd6E4z8IQuO8FgLELrdaukYHN-CSeqD3xvS_uVAyKXHrQdSIjKubAN_pU4Ow-TV827K2mcnOFjgbWBwW5tyRIu8lCvwYd_5gIiK84lv9aYQygfK9CHG1Ldk1G5_BADI8fymxnA6IzCvTPnid5x',
#      'width': 1440}],
#    'place_id': 'ChIJJ-A7DYMfmAcRmwMHcZyXb4E',
#    'plus_code': {'compound_code': '2P74+4P Nova Aldeota, Tauá - CE, Brazil',
#     'global_code': '686X2P74+4P'},
#    'rating': 4.5,
#    'reference': 'ChIJJ-A7DYMfmAcRmwMHcZyXb4E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'Rua Torquato R da Silva - Nova Aldeota, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.988765700000001, 'lng': -40.2963333},
#     'viewport': {'northeast': {'lat': -5.987667869708498,
#       'lng': -40.2949234197085},
#      'southwest': {'lat': -5.990365830291503, 'lng': -40.2976213802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Duplex Planalto Nelandia',
#    'place_id': 'ChIJbUT0A3cfmAcRhBzh13NPlmQ',
#    'plus_code': {'compound_code': '2P63+FF Doutor Jose Osimo, Tauá - CE, Brazil',
#     'global_code': '686X2P63+FF'},
#    'rating': 4,
#    'reference': 'ChIJbUT0A3cfmAcRhBzh13NPlmQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': '114, Rua Alberto de Sousa Mota, 2 - Doutor Jose Osimo, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.9892749, 'lng': -40.2954762},
#     'viewport': {'northeast': {'lat': -5.987917769708498,
#       'lng': -40.2940752197085},
#      'southwest': {'lat': -5.990615730291502, 'lng': -40.2967731802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Pousada Singular',
#    'photos': [{'height': 2592,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110778952445121241377">Evangeline Alves</a>'],
#      'photo_reference': 'Aap_uEAKam5LnS7KjgiL4BR2sZ62gHyzxo0SswIJ3M6vslnIHtppYBjBWRwEhTMOeJzTZ_dACb8APLBNsnPRgg8B27nSHf5IErHiAv0__QemtWraRtWs2MrvUEFi3CSuhI0W6qX33o_crDfqR78qihHiDHQ24MmN59je_pCzsi6nmP0uzt0f',
#      'width': 1944}],
#    'place_id': 'ChIJmb5e5XYfmAcRyYNfqMuIP_4',
#    'plus_code': {'compound_code': '2P63+7R Doutor Jose Osimo, Tauá - CE, Brazil',
#     'global_code': '686X2P63+7R'},
#    'rating': 4.5,
#    'reference': 'ChIJmb5e5XYfmAcRyYNfqMuIP_4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 54,
#    'vicinity': 'av dr, Avenida Odilon Aguiar, 2027 - Doutor Jose Osimo, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.990670699999999, 'lng': -40.2958669},
#     'viewport': {'northeast': {'lat': -5.989400419708498,
#       'lng': -40.29451476970851},
#      'southwest': {'lat': -5.992098380291503, 'lng': -40.29721273029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Recanto Morada Nova',
#    'photos': [{'height': 1836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112683598976746908884">Maria Iraneide de Souza Souza</a>'],
#      'photo_reference': 'Aap_uECEmBzvpIoATrbCbp2rgqn_VTK3F0-DOjzOpfywy9VEB1BvBB3EylHFeQT6ttcl122um0UcFNCgbuo5cVt2aiengZYinI8s3t_OyRIOUX6OpoLCullccL6fs2Wyidi11oeOZQ-NLWNnzOLNOk2pzrMJmWfiyjqKF_mGs_0LEGmPARMA',
#      'width': 3264}],
#    'place_id': 'ChIJJ545BVMfmAcRRUSvX5-Tk64',
#    'plus_code': {'compound_code': '2P53+PM Arneiroz - State of Ceará, Brazil',
#     'global_code': '686X2P53+PM'},
#    'reference': 'ChIJJ545BVMfmAcRRUSvX5-Tk64',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Arneiroz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.9920715, 'lng': -40.2937248},
#     'viewport': {'northeast': {'lat': -5.990723919708498,
#       'lng': -40.2924005197085},
#      'southwest': {'lat': -5.993421880291502, 'lng': -40.2950984802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Casa Francisco',
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103909150111882062369">palhaço pepeto</a>'],
#      'photo_reference': 'Aap_uEAnj4qfEUgcjUsR4mSGctPH7QQ5cf_edeiaqPbyTggvSJ5LTwi_-sQFiIyTXRDzRkZ7-_gvjvNWvMh_A9dRQ6kMSw789GowRFsGpREYprBgTzD4_tgZQxqaFMyd7iqw20lRbLlaup-gTl5tmJCgGlrJHbdCFrkD4WbrUJkeBWw9czDb',
#      'width': 1836}],
#    'place_id': 'ChIJkQLJZGEfmAcRmPQRtXqZCpo',
#    'plus_code': {'compound_code': '2P54+5G Doutor Jose Osimo, Tauá - CE, Brazil',
#     'global_code': '686X2P54+5G'},
#    'rating': 3.8,
#    'reference': 'ChIJkQLJZGEfmAcRmPQRtXqZCpo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 25,
#    'vicinity': 'Rua Dondon Feitosa, 343 - Doutor Jose Osimo, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.997200400000001, 'lng': -40.2879638},
#     'viewport': {'northeast': {'lat': -5.995822919708499,
#       'lng': -40.2865274697085},
#      'southwest': {'lat': -5.998520880291504, 'lng': -40.28922543029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Bounganville',
#    'photos': [{'height': 2250,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109751763863149948182">Salomão Barcelos Plens</a>'],
#      'photo_reference': 'Aap_uEDFvFAgMLf01XRYlSPz967q1x6RYULgrPtRmgghoCX_AthSrZbRvKwmuP3AjRCNLeIiEB8SE6sjKR9lGa0x4pIw8wgz7oLtzX_fNmF5Xa3uH4gQc2FTEWMutJRgdVYea3mClNfCd2Qem_ABe1uQrQPA4I2cJYFABq7pl4aREcFO6FYP',
#      'width': 4000}],
#    'place_id': 'ChIJabWv2hIfmAcRD7PbgwEXA3E',
#    'plus_code': {'compound_code': '2P36+4R Tauá, Brazil',
#     'global_code': '686X2P36+4R'},
#    'rating': 4.2,
#    'reference': 'ChIJabWv2hIfmAcRD7PbgwEXA3E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 141,
#    'vicinity': '3040, Rodovia da Confiança, 2980 - José Ósimo, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.004908700000001,
#      'lng': -40.29380079999999},
#     'viewport': {'northeast': {'lat': -6.003576869708498,
#       'lng': -40.29241276970851},
#      'southwest': {'lat': -6.006274830291503, 'lng': -40.2951107302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel São Silvestre',
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106143357219344510456">Wainey Teixeira</a>'],
#      'photo_reference': 'Aap_uEARsrDDK7s13nPumFipHeGYyVwBbU1s1_6_IPqzQtVq59m-QllC7mfSJuF6qfNfT-2Lfi8YYxlqWj-9ixUzNQAyeict9AznGPUQATWWd9noUw9VLlyMKJNDBvkEfS1-PJFTp7_pgAsLG59Xdfdr_L_D3puEUoWILVWDF799HtClm7jq',
#      'width': 4160}],
#    'place_id': 'ChIJ7RtLIUIfmAcRdTPQKS7XxMY',
#    'plus_code': {'compound_code': 'XPW4+2F Tauá, CE, Brazil',
#     'global_code': '685XXPW4+2F'},
#    'rating': 3.9,
#    'reference': 'ChIJ7RtLIUIfmAcRdTPQKS7XxMY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 66,
#    'vicinity': 'Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.002229, 'lng': -40.2945032},
#     'viewport': {'northeast': {'lat': -6.000871519708498,
#       'lng': -40.29318531970851},
#      'southwest': {'lat': -6.003569480291502, 'lng': -40.2958832802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Pousada Três Reis Magos',
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112732372412973796150">JOSE FLEURI QUEIROZ SOUSA</a>'],
#      'photo_reference': 'Aap_uEAKsdwoWWlbi_duk6-N7xzYbQa1oDpzIdMP25BMHBrmq_W_WxrRrjegNOf7sAk4XCRK46uor1nva_ZmtKCipYuQDshrjJshLitNYnMxPWNpVVX217BpCtsqhquVBIFF1HwCY3t5_ASWkxVG9A0sNcztJiTNzh5B4dMHWRm2sdKsAFV2',
#      'width': 1800}],
#    'place_id': 'ChIJn8gvQpofmAcRXP0PfbObbjg',
#    'plus_code': {'compound_code': 'XPX4+45 Centro, Tauá - CE, Brazil',
#     'global_code': '685XXPX4+45'},
#    'rating': 4,
#    'reference': 'ChIJn8gvQpofmAcRXP0PfbObbjg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 17,
#    'vicinity': 'Galeria 3 Reis Magos, 118 - Centro, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.993601600000001, 'lng': -40.2740332},
#     'viewport': {'northeast': {'lat': -5.992582669708498,
#       'lng': -40.27235416970851},
#      'southwest': {'lat': -5.995280630291503, 'lng': -40.2750521302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Dormitório',
#    'photos': [{'height': 2193,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105093402813116024907">Germano Silva</a>'],
#      'photo_reference': 'Aap_uED2RLwQ2qII5q67fTzTQHoeBeJWMBLmz80COO_4G-xOAZeg1vcwi1ooDyO051XoWx5hxpZPIrDYd3YCum4xYRYoHw-ehzxfGr1d-H68_Jqnunr1aa3Shv9aDMRUrD-Kc0L1XFLYkRuxA9MmYIInZOZ6yxkXM3Vw8-PuCwNejvm63ias',
#      'width': 4064}],
#    'place_id': 'ChIJ5Vx0CgMfmAcRQA9W1dj3S9Q',
#    'plus_code': {'compound_code': '2P4G+H9 Tauá, Brazil',
#     'global_code': '686X2P4G+H9'},
#    'rating': 3.7,
#    'reference': 'ChIJ5Vx0CgMfmAcRQA9W1dj3S9Q',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': 'CE-168, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.0021232, 'lng': -40.28587109999999},
#     'viewport': {'northeast': {'lat': -6.000811219708497,
#       'lng': -40.28462391970849},
#      'southwest': {'lat': -6.003509180291502, 'lng': -40.28732188029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Julião',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1856,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112211357934047734956">Hotel Julião</a>'],
#      'photo_reference': 'Aap_uECj4vJGJKlEK-CL3Qjj_PlrTq0Wwr4q57hsJpafbHu0oE20IXnsPa0Vsrxij_Z0VWpCaD3fEn2358_VqWtrDMKkYdBGB9bgIGkGHPajuYhmb_qIjmdp52RqWSy3ENUbbMsDS_AheOGTgRWKFDlRBeZEF92rEsZmcHMEkE5LzftWOcQ3',
#      'width': 3000}],
#    'place_id': 'ChIJy2S6qhUfmAcRarKzqvbeFpw',
#    'plus_code': {'compound_code': 'XPX7+5M Tauá, Brazil',
#     'global_code': '685XXPX7+5M'},
#    'rating': 4.4,
#    'reference': 'ChIJy2S6qhUfmAcRarKzqvbeFpw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 255,
#    'vicinity': 'Avenida Chermont Alves de Oliveira, 1799 - Chiquinho Parmênio, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.9959244, 'lng': -40.2742347},
#     'viewport': {'northeast': {'lat': -5.994373719708498,
#       'lng': -40.2730890197085},
#      'southwest': {'lat': -5.997071680291501, 'lng': -40.2757869802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Bora Bora Motel',
#    'place_id': 'ChIJBxD0UJsfmAcR9k38YX3fclg',
#    'plus_code': {'compound_code': '2P3G+J8 Tauá, Brazil',
#     'global_code': '686X2P3G+J8'},
#    'rating': 4.4,
#    'reference': 'ChIJBxD0UJsfmAcR9k38YX3fclg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 23,
#    'vicinity': 'CE-168, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.002868, 'lng': -40.28567299999999},
#     'viewport': {'northeast': {'lat': -6.001567019708498,
#       'lng': -40.2843963197085},
#      'southwest': {'lat': -6.004264980291502, 'lng': -40.28709428029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Pousada Durma Bem',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109332247443828935544">Jonatas Fernandes da Silva</a>'],
#      'photo_reference': 'Aap_uECwiEuoJ1Dq8HYwjy3H5n-rE40TJulfiuyQIK4XUXkQgEwKviO8h59K_3DE7QAyEAUZ6BKB8fV4htmHp-SRKbjzrtGv0L5ErMR3_-MVx84N698h1g8x100EVo67LcbSKsB8-xCIt9xoqXbuff_Y1fHXpdQeHOhymItNZ-Ebv4Lgm7hh',
#      'width': 4032}],
#    'place_id': 'ChIJrawZmBUfmAcRKU_mg9Jydng',
#    'plus_code': {'compound_code': 'XPW7+VP Alto Brilhante, Tauá - CE, Brazil',
#     'global_code': '685XXPW7+VP'},
#    'rating': 4.2,
#    'reference': 'ChIJrawZmBUfmAcRKU_mg9Jydng',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 258,
#    'vicinity': 'Rua da Esperança, 1903 - Alto Brilhante, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.004754999999999,
#      'lng': -40.28501649999999},
#     'viewport': {'northeast': {'lat': -6.003433869708498,
#       'lng': -40.28375506970849},
#      'southwest': {'lat': -6.006131830291502, 'lng': -40.28645303029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Pousada Pedrosa',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107333992020596651732">Luis Pedrosa</a>'],
#      'photo_reference': 'Aap_uEAsioZGe-Es462k2XkKGDwKGkLbiK0liR8L3LXBx5QJyyxzIIaQIpTV5X68a4MZJQ-fvqMjWf4XVSKfUyJGwU9CmyaAyd5Q6mNu2qmOg81HjQ6IWYuXFClXt90ELi1Y4MGuDRhEqz_-lQeCi-ORnlOxYMpaZQf1ywwmqk57n4ra0rGg',
#      'width': 1920}],
#    'place_id': 'ChIJbSTrJD4fmAcRvD0fxa9BjvI',
#    'plus_code': {'compound_code': 'XPW7+3X Alto Brilhante, Tauá - CE, Brazil',
#     'global_code': '685XXPW7+3X'},
#    'rating': 3.5,
#    'reference': 'ChIJbSTrJD4fmAcRvD0fxa9BjvI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 31,
#    'vicinity': 'Avenida Chermont Alves de Oliveira, 2041 - Alto Brilhante, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.0073983, 'lng': -40.2950636},
#     'viewport': {'northeast': {'lat': -6.006069669708498,
#       'lng': -40.2937846697085},
#      'southwest': {'lat': -6.008767630291502, 'lng': -40.29648263029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'APEOC - Tauá',
#    'place_id': 'ChIJMbUlGk4fmAcRJg9fbc9qx8c',
#    'plus_code': {'compound_code': 'XPV3+2X Tauazinho, Tauá - CE, Brazil',
#     'global_code': '685XXPV3+2X'},
#    'reference': 'ChIJMbUlGk4fmAcRJg9fbc9qx8c',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Avenida Coronel Vicente Alexandrino Souza, 339 - Tauazinho, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.007700300000001,
#      'lng': -40.29359839999999},
#     'viewport': {'northeast': {'lat': -6.006382419708499,
#       'lng': -40.2923532697085},
#      'southwest': {'lat': -6.009080380291503, 'lng': -40.29505123029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel do elias',
#    'place_id': 'ChIJlcaJCaofmAcRNd6OPj46N9Q',
#    'plus_code': {'compound_code': 'XPR4+WH Tauá, CE, Brazil',
#     'global_code': '685XXPR4+WH'},
#    'reference': 'ChIJlcaJCaofmAcRNd6OPj46N9Q',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.0080018, 'lng': -40.2865179},
#     'viewport': {'northeast': {'lat': -6.006496119708498,
#       'lng': -40.28537091970851},
#      'southwest': {'lat': -6.009194080291502, 'lng': -40.2880688802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Maria Bastos',
#    'photos': [{'height': 1760,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117946334968647945261">Marlon Trindade</a>'],
#      'photo_reference': 'Aap_uEAuyED7qjR0B8ZyRTP6eaLX4M8O3Xty8RPGK0vNdAbDgf83w27p9CAJPL6XcPk1WunNAgjlMqTpzhTQ6LdaFHTFPMfaE3UYly1iZVwWMLEFP3CmIegZekwQ5_ptJ_LHhcVlluBAGa1aWeDTLJI3byvzc2MrmZ4Va5N_C1zKXfla6NgZ',
#      'width': 4096}],
#    'place_id': 'ChIJC07cMD8fmAcRmoinVKA93SE',
#    'plus_code': {'compound_code': 'XPR7+Q9 Pedregal, Tauá - CE, Brazil',
#     'global_code': '685XXPR7+Q9'},
#    'rating': 4.5,
#    'reference': 'ChIJC07cMD8fmAcRmoinVKA93SE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 637,
#    'vicinity': 'Rua Solon Medeiros, 365 - Alto Brilhante - Pedregal, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.0071641, 'lng': -40.2883003},
#     'viewport': {'northeast': {'lat': -6.005728369708498,
#       'lng': -40.2869612697085},
#      'southwest': {'lat': -6.008426330291503, 'lng': -40.2896592302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Pousada Santos',
#    'place_id': 'ChIJgfMiVMsfmAcRRQN4zZfUda8',
#    'plus_code': {'compound_code': 'XPV6+4M Bezerra de Sousa, Tauá - CE, Brazil',
#     'global_code': '685XXPV6+4M'},
#    'rating': 4,
#    'reference': 'ChIJgfMiVMsfmAcRRQN4zZfUda8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 12,
#    'vicinity': 'Unnamed Road - Bezerra de Sousa, Tauá'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -6.010362499999999, 'lng': -40.2987199},
#     'viewport': {'northeast': {'lat': -6.008967769708497,
#       'lng': -40.2973876697085},
#      'southwest': {'lat': -6.011665730291502, 'lng': -40.3000856302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hermógenes alves Caracas',
#    'place_id': 'ChIJdbBlg58fmAcRYGIFn1zNvLE',
#    'plus_code': {'compound_code': 'XPQ2+VG Conjunto Habitacional Joel Marques, Tauá - CE, Brazil',
#     'global_code': '685XXPQ2+VG'},
#    'reference': 'ChIJdbBlg58fmAcRYGIFn1zNvLE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Rua Anderson Ferreira dos Réis, 279 - Conjunto Habitacional Joel Marques, Tauá'}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 20

# %%
#Grab the first hotel from the results and store the name.

i=0
for element in enumerate(hotels):
    
    hotels["results"][i]["name"]
    
    print(hotels["results"][i]["name"])

    i=i+1
# Out:
# Chácara Paraíso
# Love Star Motel
# Aldeota City
# Duplex Planalto Nelandia

# %%
hotel_df
# Out:
#                City Country  Max Temp      Lat       Lng Hotel Name
# 3            Nsanje      MW     75.13 -16.9200   35.2620
# 9             Kapaa      US     78.78  22.0752 -159.3190
# 15     Puerto Ayora      EC     85.96  -0.7393  -90.3518
# 18             Tual      ID     82.27  -5.6667  132.7500
# 19    Mar del Plata      AR     80.62 -38.0023  -57.5575
# ..              ...     ...       ...      ...       ...        ...
# 549  Puerto Lempira      HN     89.74  15.2667  -83.7667
# 553           Posse      BR     81.52 -14.0931  -46.3694
# 557           Lubao      PH     75.27  14.9167  120.5500
# 560      Svay Rieng      KH     80.33  11.0879  105.7993
# 563            Tauá      BR     78.71  -5.9667  -40.3000
#
# [195 rows x 6 columns]
