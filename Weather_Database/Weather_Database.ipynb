# %%
# Dependencies 
import pandas as pd 
import numpy as np
import random
from citipy import citipy
from config import weather_api_key
import requests

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)

# Count amount of unique cities
len(cities)
# Out:
# 762

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

 # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | chuy
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | strezhevoy
# Processing Record 6 of Set 1 | padang
# Processing Record 7 of Set 1 | rascani
# City not found. Skipping
# Processing Record 8 of Set 1 | tsihombe
# City not found. Skipping
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | nouakchott
# Processing Record 11 of Set 1 | chulym
# Processing Record 12 of Set 1 | faya
# Processing Record 13 of Set 1 | cockburn town
# Processing Record 14 of Set 1 | paamiut
# Processing Record 15 of Set 1 | sao joao da barra
# Processing Record 16 of Set 1 | mergui
# City not found. Skipping
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | mount isa
# Processing Record 22 of Set 1 | pontianak
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | klaksvik
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | port macquarie
# Processing Record 28 of Set 1 | codrington
# Processing Record 29 of Set 1 | bambous virieux
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | panama city
# Processing Record 32 of Set 1 | stabat
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | itaituba
# Processing Record 35 of Set 1 | adrar
# Processing Record 36 of Set 1 | springdale
# Processing Record 37 of Set 1 | sitka
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | roald
# Processing Record 40 of Set 1 | comodoro rivadavia
# Processing Record 41 of Set 1 | scarborough
# Processing Record 42 of Set 1 | souillac
# Processing Record 43 of Set 1 | rio bananal
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | itarema
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | tigzirt
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | parras
# City not found. Skipping
# Processing Record 4 of Set 2 | chilca
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | homer
# Processing Record 7 of Set 2 | pisco
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | ahipara
# Processing Record 11 of Set 2 | wukari
# Processing Record 12 of Set 2 | katsuura
# Processing Record 13 of Set 2 | almaznyy
# Processing Record 14 of Set 2 | tautira
# Processing Record 15 of Set 2 | joshimath
# Processing Record 16 of Set 2 | nizhniy kuranakh
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | jiujiang
# Processing Record 22 of Set 2 | fiche
# Processing Record 23 of Set 2 | jalu
# Processing Record 24 of Set 2 | manokwari
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | kulhudhuffushi
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | marshall
# Processing Record 30 of Set 2 | three hills
# Processing Record 31 of Set 2 | nerchinskiy zavod
# Processing Record 32 of Set 2 | abong mbang
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | namibe
# Processing Record 35 of Set 2 | hambantota
# Processing Record 36 of Set 2 | lavrentiya
# Processing Record 37 of Set 2 | aksu
# Processing Record 38 of Set 2 | araruna
# Processing Record 39 of Set 2 | ucluelet
# Processing Record 40 of Set 2 | russell
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | mezen
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | zhanaozen
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | monteagudo
# Processing Record 48 of Set 2 | honiara
# Processing Record 49 of Set 2 | socorro
# Processing Record 50 of Set 2 | hamilton
# Processing Record 1 of Set 3 | tiksi
# Processing Record 2 of Set 3 | dakar
# Processing Record 3 of Set 3 | tungkang
# City not found. Skipping
# Processing Record 4 of Set 3 | bereda
# Processing Record 5 of Set 3 | geraldton
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | faanui
# Processing Record 8 of Set 3 | san quintin
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping
# Processing Record 10 of Set 3 | jega
# Processing Record 11 of Set 3 | ottumwa
# Processing Record 12 of Set 3 | saldanha
# Processing Record 13 of Set 3 | esperance
# Processing Record 14 of Set 3 | pinheiro machado
# Processing Record 15 of Set 3 | ciuperceni
# Processing Record 16 of Set 3 | sao jose da coroa grande
# Processing Record 17 of Set 3 | tasiilaq
# Processing Record 18 of Set 3 | sentyabrskiy
# City not found. Skipping
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 3 | college
# Processing Record 22 of Set 3 | kamenskoye
# City not found. Skipping
# Processing Record 23 of Set 3 | port-gentil
# Processing Record 24 of Set 3 | kavaratti
# Processing Record 25 of Set 3 | derzhavinsk
# Processing Record 26 of Set 3 | rudnogorsk
# Processing Record 27 of Set 3 | ampanihy
# Processing Record 28 of Set 3 | rundu
# Processing Record 29 of Set 3 | mazyr
# Processing Record 30 of Set 3 | alofi
# Processing Record 31 of Set 3 | santa marta
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping
# Processing Record 34 of Set 3 | sidi qasim
# City not found. Skipping
# Processing Record 35 of Set 3 | broome
# Processing Record 36 of Set 3 | kazalinsk
# City not found. Skipping
# Processing Record 37 of Set 3 | lima
# Processing Record 38 of Set 3 | pevek
# Processing Record 39 of Set 3 | upernavik
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping
# Processing Record 41 of Set 3 | peniche
# Processing Record 42 of Set 3 | isangel
# Processing Record 43 of Set 3 | aklavik
# Processing Record 44 of Set 3 | amboasary
# Processing Record 45 of Set 3 | severo-kurilsk
# Processing Record 46 of Set 3 | saleaula
# City not found. Skipping
# Processing Record 47 of Set 3 | sola
# Processing Record 48 of Set 3 | dosso
# Processing Record 49 of Set 3 | qafsah
# City not found. Skipping
# Processing Record 50 of Set 3 | tarjan
# Processing Record 1 of Set 4 | agadez
# Processing Record 2 of Set 4 | puerto ayora
# Processing Record 3 of Set 4 | guerrero negro
# Processing Record 4 of Set 4 | barcelos
# Processing Record 5 of Set 4 | kiama
# Processing Record 6 of Set 4 | hermanus
# Processing Record 7 of Set 4 | maun
# Processing Record 8 of Set 4 | lazaro cardenas
# Processing Record 9 of Set 4 | butaritari
# Processing Record 10 of Set 4 | artyk
# City not found. Skipping
# Processing Record 11 of Set 4 | karakol
# Processing Record 12 of Set 4 | san lorenzo
# Processing Record 13 of Set 4 | suntar
# Processing Record 14 of Set 4 | moengo
# Processing Record 15 of Set 4 | silver city
# Processing Record 16 of Set 4 | chaihe
# Processing Record 17 of Set 4 | alice springs
# Processing Record 18 of Set 4 | taltal
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | ilulissat
# Processing Record 21 of Set 4 | vallenar
# Processing Record 22 of Set 4 | barentsburg
# City not found. Skipping
# Processing Record 23 of Set 4 | khandyga
# Processing Record 24 of Set 4 | sungaipenuh
# Processing Record 25 of Set 4 | ukiah
# Processing Record 26 of Set 4 | cazaje
# City not found. Skipping
# Processing Record 27 of Set 4 | quatre cocos
# Processing Record 28 of Set 4 | cairns
# Processing Record 29 of Set 4 | greenfield
# Processing Record 30 of Set 4 | keti bandar
# Processing Record 31 of Set 4 | khonuu
# City not found. Skipping
# Processing Record 32 of Set 4 | emerald
# Processing Record 33 of Set 4 | torbay
# Processing Record 34 of Set 4 | kahului
# Processing Record 35 of Set 4 | cayenne
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | sioux lookout
# Processing Record 38 of Set 4 | yirol
# City not found. Skipping
# Processing Record 39 of Set 4 | koster
# Processing Record 40 of Set 4 | samusu
# City not found. Skipping
# Processing Record 41 of Set 4 | venado tuerto
# Processing Record 42 of Set 4 | bairiki
# Processing Record 43 of Set 4 | kamina
# Processing Record 44 of Set 4 | yerbogachen
# Processing Record 45 of Set 4 | caravelas
# Processing Record 46 of Set 4 | kungurtug
# Processing Record 47 of Set 4 | coihaique
# Processing Record 48 of Set 4 | tuatapere
# Processing Record 49 of Set 4 | hasaki
# Processing Record 50 of Set 4 | conceicao da barra
# Processing Record 1 of Set 5 | abha
# Processing Record 2 of Set 5 | bayji
# Processing Record 3 of Set 5 | troy
# Processing Record 4 of Set 5 | sorong
# Processing Record 5 of Set 5 | shelburne
# Processing Record 6 of Set 5 | jinchang
# Processing Record 7 of Set 5 | camacha
# Processing Record 8 of Set 5 | tazovskiy
# Processing Record 9 of Set 5 | agirish
# Processing Record 10 of Set 5 | namatanai
# Processing Record 11 of Set 5 | isla vista
# Processing Record 12 of Set 5 | luderitz
# Processing Record 13 of Set 5 | fairlie
# Processing Record 14 of Set 5 | selenginsk
# Processing Record 15 of Set 5 | dikson
# Processing Record 16 of Set 5 | najran
# Processing Record 17 of Set 5 | kodiak
# Processing Record 18 of Set 5 | manzhouli
# Processing Record 19 of Set 5 | san luis
# Processing Record 20 of Set 5 | dingle
# Processing Record 21 of Set 5 | naze
# Processing Record 22 of Set 5 | poum
# Processing Record 23 of Set 5 | chapais
# Processing Record 24 of Set 5 | long xuyen
# Processing Record 25 of Set 5 | autun
# Processing Record 26 of Set 5 | ayan
# Processing Record 27 of Set 5 | qasigiannguit
# Processing Record 28 of Set 5 | san francisco
# Processing Record 29 of Set 5 | ruatoria
# City not found. Skipping
# Processing Record 30 of Set 5 | hervey bay
# Processing Record 31 of Set 5 | ribeira brava
# Processing Record 32 of Set 5 | tabou
# Processing Record 33 of Set 5 | darnah
# Processing Record 34 of Set 5 | bengkulu
# Processing Record 35 of Set 5 | atlantic city
# Processing Record 36 of Set 5 | mudgee
# Processing Record 37 of Set 5 | ola
# Processing Record 38 of Set 5 | turochak
# Processing Record 39 of Set 5 | yumen
# Processing Record 40 of Set 5 | maceio
# Processing Record 41 of Set 5 | kampene
# Processing Record 42 of Set 5 | thinadhoo
# Processing Record 43 of Set 5 | cherskiy
# Processing Record 44 of Set 5 | krasnomayskiy
# Processing Record 45 of Set 5 | alta floresta
# Processing Record 46 of Set 5 | nador
# Processing Record 47 of Set 5 | luklukan
# Processing Record 48 of Set 5 | hobart
# Processing Record 49 of Set 5 | utena
# Processing Record 50 of Set 5 | fairbanks
# Processing Record 1 of Set 6 | hay river
# Processing Record 2 of Set 6 | marcona
# City not found. Skipping
# Processing Record 3 of Set 6 | touros
# Processing Record 4 of Set 6 | santa rosa
# Processing Record 5 of Set 6 | marzuq
# Processing Record 6 of Set 6 | pemba
# Processing Record 7 of Set 6 | iberia
# Processing Record 8 of Set 6 | petershagen
# Processing Record 9 of Set 6 | armacao dos buzios
# City not found. Skipping
# Processing Record 10 of Set 6 | santa marinella
# Processing Record 11 of Set 6 | orthez
# Processing Record 12 of Set 6 | kjopsvik
# Processing Record 13 of Set 6 | berlevag
# Processing Record 14 of Set 6 | hemsedal
# Processing Record 15 of Set 6 | sinjar
# Processing Record 16 of Set 6 | taldan
# Processing Record 17 of Set 6 | tavda
# Processing Record 18 of Set 6 | dolores
# Processing Record 19 of Set 6 | galiwinku
# City not found. Skipping
# Processing Record 20 of Set 6 | porechye-rybnoye
# Processing Record 21 of Set 6 | temba
# Processing Record 22 of Set 6 | talah
# City not found. Skipping
# Processing Record 23 of Set 6 | mercedes
# Processing Record 24 of Set 6 | lorengau
# Processing Record 25 of Set 6 | thompson
# Processing Record 26 of Set 6 | we
# City not found. Skipping
# Processing Record 27 of Set 6 | beloha
# Processing Record 28 of Set 6 | tocopilla
# Processing Record 29 of Set 6 | klaebu
# Processing Record 30 of Set 6 | modasa
# Processing Record 31 of Set 6 | ciumeghiu
# Processing Record 32 of Set 6 | guajara-mirim
# City not found. Skipping
# Processing Record 33 of Set 6 | palmares do sul
# Processing Record 34 of Set 6 | brae
# Processing Record 35 of Set 6 | bandarbeyla
# Processing Record 36 of Set 6 | northampton
# Processing Record 37 of Set 6 | batagay
# Processing Record 38 of Set 6 | airai
# Processing Record 39 of Set 6 | gigmoto
# Processing Record 40 of Set 6 | deputatskiy
# Processing Record 41 of Set 6 | coquimbo
# Processing Record 42 of Set 6 | yar-sale
# Processing Record 43 of Set 6 | pringsewu
# Processing Record 44 of Set 6 | san julian
# Processing Record 45 of Set 6 | tilichiki
# Processing Record 46 of Set 6 | prichard
# Processing Record 47 of Set 6 | mayumba
# Processing Record 48 of Set 6 | bowen
# Processing Record 49 of Set 6 | charters towers
# Processing Record 50 of Set 6 | morondava
# Processing Record 1 of Set 7 | natchitoches
# Processing Record 2 of Set 7 | mariestad
# Processing Record 3 of Set 7 | tomigusuku
# Processing Record 4 of Set 7 | poya
# Processing Record 5 of Set 7 | ventersburg
# Processing Record 6 of Set 7 | hunza
# City not found. Skipping
# Processing Record 7 of Set 7 | kuche
# City not found. Skipping
# Processing Record 8 of Set 7 | daru
# Processing Record 9 of Set 7 | nanortalik
# Processing Record 10 of Set 7 | tuktoyaktuk
# Processing Record 11 of Set 7 | mazamari
# Processing Record 12 of Set 7 | ulladulla
# Processing Record 13 of Set 7 | wasilla
# Processing Record 14 of Set 7 | sao filipe
# Processing Record 15 of Set 7 | kartuzy
# Processing Record 16 of Set 7 | upington
# Processing Record 17 of Set 7 | tlahualilo
# City not found. Skipping
# Processing Record 18 of Set 7 | waingapu
# Processing Record 19 of Set 7 | longonjo
# Processing Record 20 of Set 7 | chicama
# Processing Record 21 of Set 7 | menongue
# Processing Record 22 of Set 7 | porto torres
# Processing Record 23 of Set 7 | kampot
# Processing Record 24 of Set 7 | vardo
# Processing Record 25 of Set 7 | calama
# Processing Record 26 of Set 7 | tessalit
# Processing Record 27 of Set 7 | denpasar
# Processing Record 28 of Set 7 | fukue
# Processing Record 29 of Set 7 | guelavia
# City not found. Skipping
# Processing Record 30 of Set 7 | vao
# Processing Record 31 of Set 7 | karakendzha
# City not found. Skipping
# Processing Record 32 of Set 7 | boyolangu
# Processing Record 33 of Set 7 | livingstone
# Processing Record 34 of Set 7 | kautokeino
# Processing Record 35 of Set 7 | karaul
# City not found. Skipping
# Processing Record 36 of Set 7 | nkawkaw
# Processing Record 37 of Set 7 | belushya guba
# City not found. Skipping
# Processing Record 38 of Set 7 | alihe
# Processing Record 39 of Set 7 | ambon
# Processing Record 40 of Set 7 | cidreira
# Processing Record 41 of Set 7 | chuguyevka
# Processing Record 42 of Set 7 | okmulgee
# Processing Record 43 of Set 7 | bam
# Processing Record 44 of Set 7 | tazmalt
# Processing Record 45 of Set 7 | novyy urgal
# Processing Record 46 of Set 7 | ternate
# Processing Record 47 of Set 7 | avera
# Processing Record 48 of Set 7 | bababe
# City not found. Skipping
# Processing Record 49 of Set 7 | cabo san lucas
# Processing Record 50 of Set 7 | clyde river
# Processing Record 1 of Set 8 | skive
# Processing Record 2 of Set 8 | dawson creek
# Processing Record 3 of Set 8 | kamaishi
# Processing Record 4 of Set 8 | anadyr
# Processing Record 5 of Set 8 | yeniseysk
# Processing Record 6 of Set 8 | menomonie
# Processing Record 7 of Set 8 | tanout
# Processing Record 8 of Set 8 | naftah
# City not found. Skipping
# Processing Record 9 of Set 8 | karratha
# Processing Record 10 of Set 8 | vrangel
# Processing Record 11 of Set 8 | bridlington
# Processing Record 12 of Set 8 | tambilil
# Processing Record 13 of Set 8 | san jeronimo
# Processing Record 14 of Set 8 | mount gambier
# Processing Record 15 of Set 8 | diamantina
# Processing Record 16 of Set 8 | ponta do sol
# Processing Record 17 of Set 8 | ostrovnoy
# Processing Record 18 of Set 8 | te anau
# Processing Record 19 of Set 8 | marovoay
# Processing Record 20 of Set 8 | chabahar
# Processing Record 21 of Set 8 | baruun-urt
# Processing Record 22 of Set 8 | komsomolskiy
# Processing Record 23 of Set 8 | puerto del rosario
# Processing Record 24 of Set 8 | garowe
# Processing Record 25 of Set 8 | east london
# Processing Record 26 of Set 8 | balykshi
# Processing Record 27 of Set 8 | attawapiskat
# City not found. Skipping
# Processing Record 28 of Set 8 | kieta
# Processing Record 29 of Set 8 | cumberland
# Processing Record 30 of Set 8 | murchison
# Processing Record 31 of Set 8 | beeville
# Processing Record 32 of Set 8 | santa isabel
# Processing Record 33 of Set 8 | arawa
# Processing Record 34 of Set 8 | progreso
# Processing Record 35 of Set 8 | svarstad
# Processing Record 36 of Set 8 | puerto baquerizo moreno
# Processing Record 37 of Set 8 | atambua
# Processing Record 38 of Set 8 | guasdualito
# Processing Record 39 of Set 8 | chapleau
# Processing Record 40 of Set 8 | vieques
# Processing Record 41 of Set 8 | vega de alatorre
# Processing Record 42 of Set 8 | laguna de duero
# Processing Record 43 of Set 8 | itoman
# Processing Record 44 of Set 8 | hovd
# Processing Record 45 of Set 8 | oga
# Processing Record 46 of Set 8 | qaqortoq
# Processing Record 47 of Set 8 | palmer
# Processing Record 48 of Set 8 | mrirt
# City not found. Skipping
# Processing Record 49 of Set 8 | tumannyy
# City not found. Skipping
# Processing Record 50 of Set 8 | urucara
# Processing Record 1 of Set 9 | okha
# Processing Record 2 of Set 9 | lawton
# Processing Record 3 of Set 9 | comandau
# Processing Record 4 of Set 9 | araouane
# Processing Record 5 of Set 9 | tillabery
# City not found. Skipping
# Processing Record 6 of Set 9 | verkhniy lomov
# Processing Record 7 of Set 9 | marathon
# Processing Record 8 of Set 9 | phan thiet
# Processing Record 9 of Set 9 | gwadar
# Processing Record 10 of Set 9 | bosorod
# Processing Record 11 of Set 9 | taoudenni
# Processing Record 12 of Set 9 | oktyabrskoye
# Processing Record 13 of Set 9 | ibra
# Processing Record 14 of Set 9 | labuan
# Processing Record 15 of Set 9 | alampur
# Processing Record 16 of Set 9 | sabang
# Processing Record 17 of Set 9 | koumac
# Processing Record 18 of Set 9 | pacific grove
# Processing Record 19 of Set 9 | inhambane
# Processing Record 20 of Set 9 | shieli
# Processing Record 21 of Set 9 | kallupatti
# Processing Record 22 of Set 9 | petrozavodsk
# Processing Record 23 of Set 9 | okhotsk
# Processing Record 24 of Set 9 | huangnihe
# Processing Record 25 of Set 9 | sassandra
# Processing Record 26 of Set 9 | nantucket
# Processing Record 27 of Set 9 | sayanogorsk
# Processing Record 28 of Set 9 | iqaluit
# Processing Record 29 of Set 9 | grindavik
# Processing Record 30 of Set 9 | tres arroyos
# Processing Record 31 of Set 9 | altamira
# Processing Record 32 of Set 9 | grand river south east
# City not found. Skipping
# Processing Record 33 of Set 9 | murzzuschlag
# Processing Record 34 of Set 9 | cap malheureux
# Processing Record 35 of Set 9 | barbar
# City not found. Skipping
# Processing Record 36 of Set 9 | shimoda
# Processing Record 37 of Set 9 | sabha
# Processing Record 38 of Set 9 | damaturu
# Processing Record 39 of Set 9 | abashiri
# Processing Record 40 of Set 9 | moussoro
# Processing Record 41 of Set 9 | ligayan
# Processing Record 42 of Set 9 | katima mulilo
# Processing Record 43 of Set 9 | tamandare
# Processing Record 44 of Set 9 | anar darreh
# City not found. Skipping
# Processing Record 45 of Set 9 | seoul
# Processing Record 46 of Set 9 | necochea
# Processing Record 47 of Set 9 | sivaki
# Processing Record 48 of Set 9 | oum hadjer
# Processing Record 49 of Set 9 | danielskuil
# Processing Record 50 of Set 9 | noumea
# Processing Record 1 of Set 10 | pampa
# Processing Record 2 of Set 10 | roma
# Processing Record 3 of Set 10 | port hardy
# Processing Record 4 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping
# Processing Record 5 of Set 10 | inta
# Processing Record 6 of Set 10 | fare
# Processing Record 7 of Set 10 | saint-pierre
# Processing Record 8 of Set 10 | uppsala
# Processing Record 9 of Set 10 | preston
# Processing Record 10 of Set 10 | nemuro
# Processing Record 11 of Set 10 | saint-augustin
# Processing Record 12 of Set 10 | garden city
# Processing Record 13 of Set 10 | lebu
# Processing Record 14 of Set 10 | troitskoye
# Processing Record 15 of Set 10 | choya
# Processing Record 16 of Set 10 | calvinia
# Processing Record 17 of Set 10 | sirvintos
# Processing Record 18 of Set 10 | sakaraha
# Processing Record 19 of Set 10 | ponta delgada
# Processing Record 20 of Set 10 | gushikawa
# Processing Record 21 of Set 10 | mossendjo
# Processing Record 22 of Set 10 | doha
# Processing Record 23 of Set 10 | launceston
# Processing Record 24 of Set 10 | lasa
# Processing Record 25 of Set 10 | gizo
# Processing Record 26 of Set 10 | talaja
# Processing Record 27 of Set 10 | plouzane
# Processing Record 28 of Set 10 | tahta
# Processing Record 29 of Set 10 | bahia blanca
# Processing Record 30 of Set 10 | zolotinka
# City not found. Skipping
# Processing Record 31 of Set 10 | belmonte
# Processing Record 32 of Set 10 | vestmannaeyjar
# Processing Record 33 of Set 10 | sangmelima
# Processing Record 34 of Set 10 | ayagoz
# Processing Record 35 of Set 10 | sobolevo
# Processing Record 36 of Set 10 | valdivia
# Processing Record 37 of Set 10 | nalvo
# Processing Record 38 of Set 10 | salalah
# Processing Record 39 of Set 10 | rocha
# Processing Record 40 of Set 10 | dano
# Processing Record 41 of Set 10 | george
# Processing Record 42 of Set 10 | idrinskoye
# Processing Record 43 of Set 10 | djambala
# Processing Record 44 of Set 10 | udachnyy
# Processing Record 45 of Set 10 | saint george
# Processing Record 46 of Set 10 | ngunguru
# Processing Record 47 of Set 10 | torrington
# Processing Record 48 of Set 10 | san jose
# Processing Record 49 of Set 10 | havre-saint-pierre
# Processing Record 50 of Set 10 | moron
# Processing Record 1 of Set 11 | mana
# Processing Record 2 of Set 11 | alekseyevsk
# Processing Record 3 of Set 11 | oranjemund
# Processing Record 4 of Set 11 | uni
# Processing Record 5 of Set 11 | tokur
# Processing Record 6 of Set 11 | north bend
# Processing Record 7 of Set 11 | muncar
# Processing Record 8 of Set 11 | corinto
# Processing Record 9 of Set 11 | halalo
# City not found. Skipping
# Processing Record 10 of Set 11 | port keats
# Processing Record 11 of Set 11 | samalaeulu
# City not found. Skipping
# Processing Record 12 of Set 11 | raudeberg
# Processing Record 13 of Set 11 | mekhelta
# City not found. Skipping
# Processing Record 14 of Set 11 | ixtapa
# Processing Record 15 of Set 11 | drabiv
# Processing Record 16 of Set 11 | flin flon
# Processing Record 17 of Set 11 | arman
# Processing Record 18 of Set 11 | natal
# Processing Record 19 of Set 11 | buin
# Processing Record 20 of Set 11 | siddhapur
# Processing Record 21 of Set 11 | rio grande
# Processing Record 22 of Set 11 | amapa
# Processing Record 23 of Set 11 | marystown
# Processing Record 24 of Set 11 | xining
# Processing Record 25 of Set 11 | murgab
# Processing Record 26 of Set 11 | ballina
# Processing Record 27 of Set 11 | sibolga
# Processing Record 28 of Set 11 | qinzhou
# Processing Record 29 of Set 11 | mezhdurechensk
# Processing Record 30 of Set 11 | provideniya
# Processing Record 31 of Set 11 | ojinaga
# Processing Record 32 of Set 11 | wuwei
# Processing Record 33 of Set 11 | goderich
# Processing Record 34 of Set 11 | jatiroto
# Processing Record 35 of Set 11 | paducah
# Processing Record 36 of Set 11 | irbil
# Processing Record 37 of Set 11 | ciudad bolivar
# Processing Record 38 of Set 11 | phan rang
# City not found. Skipping
# Processing Record 39 of Set 11 | bocas del toro
# Processing Record 40 of Set 11 | ituni
# City not found. Skipping
# Processing Record 41 of Set 11 | beringovskiy
# Processing Record 42 of Set 11 | semey
# Processing Record 43 of Set 11 | balgazyn
# Processing Record 44 of Set 11 | innisfail
# Processing Record 45 of Set 11 | chipinge
# Processing Record 46 of Set 11 | jumla
# Processing Record 47 of Set 11 | fort morgan
# Processing Record 48 of Set 11 | toktogul
# Processing Record 49 of Set 11 | biak
# Processing Record 50 of Set 11 | husavik
# Processing Record 1 of Set 12 | lomza
# Processing Record 2 of Set 12 | ous
# Processing Record 3 of Set 12 | nioro
# Processing Record 4 of Set 12 | kribi
# Processing Record 5 of Set 12 | yuci
# Processing Record 6 of Set 12 | gurgan
# City not found. Skipping
# Processing Record 7 of Set 12 | zhoucheng
# Processing Record 8 of Set 12 | joetsu
# Processing Record 9 of Set 12 | tehachapi
# Processing Record 10 of Set 12 | boa vista
# Processing Record 11 of Set 12 | cumaribo
# City not found. Skipping
# Processing Record 12 of Set 12 | parry sound
# Processing Record 13 of Set 12 | taki
# Processing Record 14 of Set 12 | ozark
# Processing Record 15 of Set 12 | saint-francois
# Processing Record 16 of Set 12 | horodnytsya
# Processing Record 17 of Set 12 | narsaq
# Processing Record 18 of Set 12 | vaitupu
# City not found. Skipping
# Processing Record 19 of Set 12 | constitucion
# Processing Record 20 of Set 12 | suruc
# Processing Record 21 of Set 12 | kidal
# Processing Record 22 of Set 12 | hauterive
# Processing Record 23 of Set 12 | tabiauea
# City not found. Skipping
# Processing Record 24 of Set 12 | camocim
# Processing Record 25 of Set 12 | pokrovskoye
# Processing Record 26 of Set 12 | merauke
# Processing Record 27 of Set 12 | blonduos
# City not found. Skipping
# Processing Record 28 of Set 12 | yantal
# Processing Record 29 of Set 12 | vanimo
# Processing Record 30 of Set 12 | omsukchan
# Processing Record 31 of Set 12 | kapit
# Processing Record 32 of Set 12 | hofn
# Processing Record 33 of Set 12 | neuquen
# Processing Record 34 of Set 12 | otavalo
# Processing Record 35 of Set 12 | nyuksenitsa
# Processing Record 36 of Set 12 | bucak
# Processing Record 37 of Set 12 | banchory
# Processing Record 38 of Set 12 | staryy nadym
# Processing Record 39 of Set 12 | afmadu
# City not found. Skipping
# Processing Record 40 of Set 12 | palabuhanratu
# City not found. Skipping
# Processing Record 41 of Set 12 | makakilo city
# Processing Record 42 of Set 12 | altay
# Processing Record 43 of Set 12 | baraganul
# Processing Record 44 of Set 12 | grand gaube
# Processing Record 45 of Set 12 | macaparana
# Processing Record 46 of Set 12 | nurota
# Processing Record 47 of Set 12 | cap-aux-meules
# Processing Record 48 of Set 12 | turka
# Processing Record 49 of Set 12 | chalus
# Processing Record 50 of Set 12 | loandjili
# Processing Record 1 of Set 13 | tombouctou
# Processing Record 2 of Set 13 | bay roberts
# Processing Record 3 of Set 13 | portland
# Processing Record 4 of Set 13 | lagoa
# Processing Record 5 of Set 13 | kabanjahe
# Processing Record 6 of Set 13 | ngudu
# Processing Record 7 of Set 13 | tselinnoye
# Processing Record 8 of Set 13 | puerto escondido
# Processing Record 9 of Set 13 | gazanjyk
# Processing Record 10 of Set 13 | maniitsoq
# Processing Record 11 of Set 13 | ostrov
# Processing Record 12 of Set 13 | puerto maldonado
# Processing Record 13 of Set 13 | port blair
# Processing Record 14 of Set 13 | arica
# Processing Record 15 of Set 13 | nome
# Processing Record 16 of Set 13 | zyryanka
# Processing Record 17 of Set 13 | tidore
# City not found. Skipping
# Processing Record 18 of Set 13 | inhuma
# Processing Record 19 of Set 13 | sindand
# City not found. Skipping
# Processing Record 20 of Set 13 | rawannawi
# City not found. Skipping
# Processing Record 21 of Set 13 | talnakh
# Processing Record 22 of Set 13 | kununurra
# Processing Record 23 of Set 13 | saint-georges
# Processing Record 24 of Set 13 | vidim
# Processing Record 25 of Set 13 | broken hill
# Processing Record 26 of Set 13 | lakhdenpokhya
# Processing Record 27 of Set 13 | canutama
# Processing Record 28 of Set 13 | bubaque
# Processing Record 29 of Set 13 | waipawa
# Processing Record 30 of Set 13 | chernyshevskiy
# Processing Record 31 of Set 13 | bury saint edmunds
# City not found. Skipping
# Processing Record 32 of Set 13 | turukhansk
# Processing Record 33 of Set 13 | mocuba
# Processing Record 34 of Set 13 | ngama
# Processing Record 35 of Set 13 | ketchikan
# Processing Record 36 of Set 13 | bilibino
# Processing Record 37 of Set 13 | estevan
# Processing Record 38 of Set 13 | mackay
# Processing Record 39 of Set 13 | niamey
# Processing Record 40 of Set 13 | tura
# Processing Record 41 of Set 13 | westport
# Processing Record 42 of Set 13 | mason city
# Processing Record 43 of Set 13 | nouadhibou
# Processing Record 44 of Set 13 | levittown
# Processing Record 45 of Set 13 | zhaotong
# Processing Record 46 of Set 13 | asau
# Processing Record 47 of Set 13 | hoquiam
# Processing Record 48 of Set 13 | mehamn
# Processing Record 49 of Set 13 | ondorhaan
# City not found. Skipping
# Processing Record 50 of Set 13 | sapernoye
# Processing Record 1 of Set 14 | belyy yar
# Processing Record 2 of Set 14 | grants
# Processing Record 3 of Set 14 | douglas
# Processing Record 4 of Set 14 | salekhard
# Processing Record 5 of Set 14 | egvekinot
# Processing Record 6 of Set 14 | fortuna
# Processing Record 7 of Set 14 | kannangad
# Processing Record 8 of Set 14 | prince albert
# Processing Record 9 of Set 14 | el ejido
# Processing Record 10 of Set 14 | port augusta
# Processing Record 11 of Set 14 | nagornyy
# Processing Record 12 of Set 14 | grand-lahou
# Processing Record 13 of Set 14 | umm lajj
# Processing Record 14 of Set 14 | udimskiy
# Processing Record 15 of Set 14 | xianyang
# Processing Record 16 of Set 14 | sandnessjoen
# Processing Record 17 of Set 14 | toliary
# City not found. Skipping
# Processing Record 18 of Set 14 | rantepao
# Processing Record 19 of Set 14 | walvis bay
# Processing Record 20 of Set 14 | longyearbyen
# Processing Record 21 of Set 14 | coahuayana
# Processing Record 22 of Set 14 | haines junction
# Processing Record 23 of Set 14 | loa janan
# Processing Record 24 of Set 14 | nkhotakota
# Processing Record 25 of Set 14 | gambela
# Processing Record 26 of Set 14 | hyderabad
# Processing Record 27 of Set 14 | kostomuksha
# Processing Record 28 of Set 14 | yerazgavors
# Processing Record 29 of Set 14 | iralaya
# Processing Record 30 of Set 14 | los llanos de aridane
# Processing Record 31 of Set 14 | bolshiye chapurniki
# City not found. Skipping
# Processing Record 32 of Set 14 | batagay-alyta
# Processing Record 33 of Set 14 | sile
# Processing Record 34 of Set 14 | shar
# Processing Record 35 of Set 14 | stantsiya gorchakovo
# City not found. Skipping
# Processing Record 36 of Set 14 | manjeshwar
# Processing Record 37 of Set 14 | whyalla
# Processing Record 38 of Set 14 | kaseda
# Processing Record 39 of Set 14 | srednekolymsk
# Processing Record 40 of Set 14 | burica
# City not found. Skipping
# Processing Record 41 of Set 14 | bonthe
# Processing Record 42 of Set 14 | issoire
# Processing Record 43 of Set 14 | steyr
# Processing Record 44 of Set 14 | lompoc
# Processing Record 45 of Set 14 | san patricio
# Processing Record 46 of Set 14 | dunedin
# Processing Record 47 of Set 14 | marigot
# Processing Record 48 of Set 14 | salinas
# Processing Record 49 of Set 14 | rosehearty
# Processing Record 50 of Set 14 | svetlogorsk
# Processing Record 1 of Set 15 | mabaruma
# Processing Record 2 of Set 15 | lourdes
# Processing Record 3 of Set 15 | yatou
# Processing Record 4 of Set 15 | kommunisticheskiy
# Processing Record 5 of Set 15 | dalhousie
# Processing Record 6 of Set 15 | manaus
# Processing Record 7 of Set 15 | gavrilovka vtoraya
# Processing Record 8 of Set 15 | voznesenye
# Processing Record 9 of Set 15 | laredo
# Processing Record 10 of Set 15 | sulangan
# Processing Record 11 of Set 15 | zhigansk
# Processing Record 12 of Set 15 | irklievskaya
# City not found. Skipping
# Processing Record 13 of Set 15 | paralimni
# Processing Record 14 of Set 15 | bambanglipuro
# Processing Record 15 of Set 15 | nishihara
# Processing Record 16 of Set 15 | hokitika
# Processing Record 17 of Set 15 | linjiang
# Processing Record 18 of Set 15 | mamakan
# Processing Record 19 of Set 15 | truth or consequences
# Processing Record 20 of Set 15 | dongkan
# Processing Record 21 of Set 15 | baraboo
# Processing Record 22 of Set 15 | kaka
# Processing Record 23 of Set 15 | kargasok
# Processing Record 24 of Set 15 | loukhi
# Processing Record 25 of Set 15 | asnaes
# Processing Record 26 of Set 15 | sayyan
# Processing Record 27 of Set 15 | yulara
# Processing Record 28 of Set 15 | greytown
# Processing Record 29 of Set 15 | viedma
# Processing Record 30 of Set 15 | banyo
# Processing Record 31 of Set 15 | miragoane
# Processing Record 32 of Set 15 | lakatoro
# Processing Record 33 of Set 15 | sri aman
# Processing Record 34 of Set 15 | suphan buri
# Processing Record 35 of Set 15 | chiredzi
# Processing Record 36 of Set 15 | muswellbrook
# Processing Record 37 of Set 15 | nisia floresta
# Processing Record 38 of Set 15 | moree
# Processing Record 39 of Set 15 | rostaq
# City not found. Skipping
# Processing Record 40 of Set 15 | atar
# Processing Record 41 of Set 15 | laguna
# Processing Record 42 of Set 15 | mishan
# Processing Record 43 of Set 15 | vodnyy
# Processing Record 44 of Set 15 | governador valadares
# Processing Record 45 of Set 15 | dwarka
# Processing Record 46 of Set 15 | sao felix do xingu
# Processing Record 47 of Set 15 | vesyegonsk
# Processing Record 48 of Set 15 | mineiros
# Processing Record 49 of Set 15 | oktyabrskiy
# Processing Record 50 of Set 15 | longlac
# City not found. Skipping
# Processing Record 1 of Set 16 | halifax
# Processing Record 2 of Set 16 | ust-kamchatsk
# City not found. Skipping
# Processing Record 3 of Set 16 | solovetskiy
# City not found. Skipping
# Processing Record 4 of Set 16 | sisimiut
# Processing Record 5 of Set 16 | massakory
# Processing Record 6 of Set 16 | guane
# Processing Record 7 of Set 16 | yinchuan
# Processing Record 8 of Set 16 | hopewell
# Processing Record 9 of Set 16 | nelson bay
# Processing Record 10 of Set 16 | koshki
# Processing Record 11 of Set 16 | alexandria
# Processing Record 12 of Set 16 | gladstone
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Chuy      UY -33.6971  -53.4616     63.95        94           2
# 1    Yellowknife      CA  62.4560 -114.3525     34.41        91         100
# 2   Punta Arenas      CL -53.1500  -70.9167     39.31        87          20
# 3     Strezhevoy      RU  60.7333   77.5889     13.33        84          49
# 4         Padang      ID  -0.9492  100.3543     86.05        62          97
# 5      Saskylakh      RU  71.9167  114.0833     10.69        92          82
# 6     Nouakchott      MR  18.0858  -15.9785     67.93        56           1
# 7         Chulym      RU  55.0997   80.9572     31.60        78          88
# 8           Faya      SA  18.3851   42.4509     53.71        30           0
# 9  Cockburn Town      TC  21.4612  -71.1419     78.19        80         100
#
#    Wind Speed Current Description
# 0        4.68           clear sky
# 1       16.11     overcast clouds
# 2        6.91          few clouds
# 3        9.13    scattered clouds
# 4        4.97     overcast clouds
# 5        3.98       broken clouds
# 6       10.13           clear sky
# 7       15.21     overcast clouds
# 8        2.15           clear sky
# 9       21.32     overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "WeatherPy_Database.csv"
# Export CSV file
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
